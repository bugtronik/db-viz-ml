# %%
# Beta tests
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Import de la data source et affichage des données de tests
df_sales_summary = pd.read_csv('../datasources/all_sales_by_products.csv')
print(df_sales_summary[['PRESTATION', 'CA HT']])
# Out:
#       PRESTATION         CA HT
# 0         Billet  3.497033e+09
# 1  Colis express  6.256877e+08
# 2         Bagage  1.499475e+08
# 3            TAA  2.222898e+08
# 4             TF  3.774344e+07

# %%
# Affichage du graphs de la synthèse des ventes mobipass sur l'ensemble de l'année 2020
sns.set_style('whitegrid')
sns.barplot(
    data=df_sales_summary,
    x='PRESTATION',
    y='CA HT',
)
plt.title("Chiffre d'affaire par prestation en 2020")
plt.xlabel('Prestations')
plt.ylabel('CA HT(Francs CFA)')

plt.show()
